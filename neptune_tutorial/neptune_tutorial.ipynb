# %% [markdown]
# ### Neptune Tutorial

# %%
import neptune.new as neptune
run = neptune.init_run(project='emmachancellor/Longitudinal-IBD', 
                       api_token='eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI3OWY4NTFhMC1hYmY1LTQ0NDQtOWE4ZS0zMDVhOGJlMjgyMTcifQ==')
# Out:
# https://app.neptune.ai/emmachancellor/Longitudinal-IBD/e/LON-4
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api/run#stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.

# %%
# Logging Hyperparameters
run["algorithm"] = "ConvNet" #this creates a field named 'algorithm' and assigns the string 'ConvNet' to it

# Create a field of the appropriate type for each dictionary entry:
params = {
    "activation": "sigmoid",
    "dropout": 0.25,
    "learning_rate": 0.1,
    "n_epochs": 100,
}

run["model/parameters"] = params
# Because of how the structure is specified ('model/parameters') the parameter fields 
# are stored in the 'parameters' namespace, nested under the 'model' namespace


# Oops, what if I want to change an existing value?
run["model/parameters/activation"] = "ReLU"

# Or add a new field: 
run["model/parameters/batch_size"] = 64

# %%
# Log Metrics

# Each log() call adds a new value to the series, so it's designed to be used in a loop
for epoch in range(params["n_epochs"]):
    # this would normally be your training loop
    run["train/loss"].log(0.99**epoch)
    run["train/acc"].log(1.01**epoch)
    run["eval/loss"].log(0.98**epoch)
    run["eval/acc"].log(1.02**epoch)
# This creates the namespaces 'train' and 'eval', each with a 'loss' and 'acc' field

# %%
# Track a data file

# track_files() allows you to log metadata about any dataset, model, or other artifact stored in a file
run["data_versions/train"].track_files("sample.csv")

# This records metadata about the CSV file in the 'data_versions/train' field, which helps identify
# the exact version of the file that was used for this run

# %%
# Upload a file

# If you want to upload the file in full to neptune then use:
run["data_sample"].upload("sample.csv")

# %%
# Stop the run

# Record some value/finish analysis:
run["f1_score"] = 0.95

# Now that we are finished logging, we can stop the run method
run.stop()

# %%
# Full Script
import neptune.new as neptune

run = neptune.init_run(project='emmachancellor/Longitudinal-IBD', 
                       api_token='eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI3OWY4NTFhMC1hYmY1LTQ0NDQtOWE4ZS0zMDVhOGJlMjgyMTcifQ==')


run["algorithm"] = "ConvNet"

params = {
    "activation": "sigmoid",
    "dropout": 0.25,
    "learning_rate": 0.1,
    "n_epochs": 100,
}
run["model/parameters"] = params

run["model/parameters/activation"] = "ReLU"
run["model/parameters/batch_size"] = 32

for epoch in range(params["n_epochs"]):
    # this would normally be your training loop
    run["train/loss"].log(0.99**epoch)
    run["train/acc"].log(1.01**epoch)
    run["eval/loss"].log(0.98**epoch)
    run["eval/acc"].log(1.02**epoch)

run["data_versions/train"].track_files("sample.csv")
run["data_sample"].upload("sample.csv")

run["f1_score"] = 0.95
# Out:
# https://app.neptune.ai/emmachancellor/Longitudinal-IBD/e/LON-5
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api/run#stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.

# %%
run.stop()
# Out:
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/emmachancellor/Longitudinal-IBD/e/LON-5
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: RequestsFutureAdapterConnectionError
# Communication with Neptune restored!
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: RequestsFutureAdapterConnectionError
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: RequestsFutureAdapterConnectionError
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: RequestsFutureAdapterConnectionError
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: RequestsFutureAdapterConnectionError
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: RequestsFutureAdapterConnectionError
# Experiencing connection interruptions. Will try to reestablish communication with Neptune. Internal exception was: RequestsFutureAdapterTimeout
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Experiencing connection interruptions. Reestablishing communication with Neptune.
# Unexpected error occurred in Neptune background thread: Killing Neptune asynchronous thread. All data is safe on disk and can be later synced manually using `neptune sync` command.
# Exception in thread NeptuneAsyncOpProcessor:
# Traceback (most recent call last):
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 230, in run
#     super().run()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 51, in run
#     self.work()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 246, in work
#     self.process_batch(batch, version)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 75, in wrapper
#     result = func(self_, *args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 262, in process_batch
#     operations=batch,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 481, in execute_operations
#     operations=itertools.chain(assign_artifact_operations, preprocessed_operations.other_operations),
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/utils.py", line 111, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 632, in _execute_operations
#     result = self.leaderboard_client.api.executeOperations(**kwargs).response().result
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 86, in __call__
#     future = self._api_method(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/client.py", line 279, in __call__
#     request_config=request_config,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 399, in request
#     self.authenticated_request(sanitized_params),
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 440, in authenticated_request
#     return self.apply_authentication(requests.Request(**request_params))
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 445, in apply_authentication
#     return self.authenticator.apply(request)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/oauth.py", line 132, in apply
#     self.auth.refresh_token_if_needed()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/utils.py", line 318, in wrapper
#     raise ConnectionLost()
# neptune.legacy.api_exceptions.ConnectionLost: Connection lost. Please try again.
# Unexpected error occurred in Neptune background thread: Killing Neptune ping thread. Your run's status will not be updated and the run will be shown as inactive.
# Unexpected error occurred in Neptune background thread: Killing Neptune asynchronous thread. All data is safe on disk and can be later synced manually using `neptune sync` command.
# Unexpected error occurred in Neptune background thread: Killing Neptune ping thread. Your run's status will not be updated and the run will be shown as inactive.
# Unexpected error occurred in Neptune background thread: Killing Neptune asynchronous thread. All data is safe on disk and can be later synced manually using `neptune sync` command.
# Unexpected error occurred in Neptune background thread: Killing Neptune ping thread. Your run's status will not be updated and the run will be shown as inactive.
# Exception in thread NeptunePing:
# Traceback (most recent call last):
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 51, in run
#     self.work()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 75, in wrapper
#     result = func(self_, *args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/utils/ping_background_job.py", line 65, in work
#     self._container.ping()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/metadata_containers/metadata_container.py", line 205, in ping
#     self._backend.ping(self._id, self.container_type)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/utils.py", line 111, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 433, in ping
#     **request_kwargs,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 86, in __call__
#     future = self._api_method(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/client.py", line 279, in __call__
#     request_config=request_config,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 399, in request
#     self.authenticated_request(sanitized_params),
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 440, in authenticated_request
#     return self.apply_authentication(requests.Request(**request_params))
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 445, in apply_authentication
#     return self.authenticator.apply(request)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/oauth.py", line 132, in apply
#     self.auth.refresh_token_if_needed()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/utils.py", line 318, in wrapper
#     raise ConnectionLost()
# neptune.legacy.api_exceptions.ConnectionLost: Connection lost. Please try again.
#
# Exception in thread NeptuneAsyncOpProcessor:
# Traceback (most recent call last):
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 230, in run
#     super().run()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 51, in run
#     self.work()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 246, in work
#     self.process_batch(batch, version)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 75, in wrapper
#     result = func(self_, *args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 262, in process_batch
#     operations=batch,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 481, in execute_operations
#     operations=itertools.chain(assign_artifact_operations, preprocessed_operations.other_operations),
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/utils.py", line 111, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 632, in _execute_operations
#     result = self.leaderboard_client.api.executeOperations(**kwargs).response().result
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 86, in __call__
#     future = self._api_method(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/client.py", line 279, in __call__
#     request_config=request_config,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 399, in request
#     self.authenticated_request(sanitized_params),
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 440, in authenticated_request
#     return self.apply_authentication(requests.Request(**request_params))
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 445, in apply_authentication
#     return self.authenticator.apply(request)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/oauth.py", line 132, in apply
#     self.auth.refresh_token_if_needed()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/utils.py", line 318, in wrapper
#     raise ConnectionLost()
# neptune.legacy.api_exceptions.ConnectionLost: Connection lost. Please try again.
#
# Exception in thread NeptunePing:
# Traceback (most recent call last):
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 51, in run
#     self.work()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 75, in wrapper
#     result = func(self_, *args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/utils/ping_background_job.py", line 65, in work
#     self._container.ping()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/metadata_containers/metadata_container.py", line 205, in ping
#     self._backend.ping(self._id, self.container_type)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/utils.py", line 111, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 433, in ping
#     **request_kwargs,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 86, in __call__
#     future = self._api_method(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/client.py", line 279, in __call__
#     request_config=request_config,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 399, in request
#     self.authenticated_request(sanitized_params),
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 440, in authenticated_request
#     return self.apply_authentication(requests.Request(**request_params))
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 445, in apply_authentication
#     return self.authenticator.apply(request)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/oauth.py", line 132, in apply
#     self.auth.refresh_token_if_needed()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/utils.py", line 318, in wrapper
#     raise ConnectionLost()
# neptune.legacy.api_exceptions.ConnectionLost: Connection lost. Please try again.
#
# Exception in thread NeptuneAsyncOpProcessor:
# Traceback (most recent call last):
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 230, in run
#     super().run()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 51, in run
#     self.work()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 246, in work
#     self.process_batch(batch, version)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 75, in wrapper
#     result = func(self_, *args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/operation_processors/async_operation_processor.py", line 262, in process_batch
#     operations=batch,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 481, in execute_operations
#     operations=itertools.chain(assign_artifact_operations, preprocessed_operations.other_operations),
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/utils.py", line 111, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 632, in _execute_operations
#     result = self.leaderboard_client.api.executeOperations(**kwargs).response().result
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 86, in __call__
#     future = self._api_method(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/client.py", line 279, in __call__
#     request_config=request_config,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 399, in request
#     self.authenticated_request(sanitized_params),
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 440, in authenticated_request
#     return self.apply_authentication(requests.Request(**request_params))
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 445, in apply_authentication
#     return self.authenticator.apply(request)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/oauth.py", line 132, in apply
#     self.auth.refresh_token_if_needed()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/utils.py", line 318, in wrapper
#     raise ConnectionLost()
# neptune.legacy.api_exceptions.ConnectionLost: Connection lost. Please try again.
#
# Exception in thread NeptunePing:
# Traceback (most recent call last):
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 51, in run
#     self.work()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/threading/daemon.py", line 75, in wrapper
#     result = func(self_, *args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/utils/ping_background_job.py", line 65, in work
#     self._container.ping()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/metadata_containers/metadata_container.py", line 205, in ping
#     self._backend.ping(self._id, self.container_type)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/utils.py", line 111, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/hosted_neptune_backend.py", line 433, in ping
#     **request_kwargs,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/new/internal/backends/swagger_client_wrapper.py", line 86, in __call__
#     future = self._api_method(*args, **kwargs)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/client.py", line 279, in __call__
#     request_config=request_config,
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 399, in request
#     self.authenticated_request(sanitized_params),
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 440, in authenticated_request
#     return self.apply_authentication(requests.Request(**request_params))
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/bravado/requests_client.py", line 445, in apply_authentication
#     return self.authenticator.apply(request)
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/oauth.py", line 132, in apply
#     self.auth.refresh_token_if_needed()
#   File "/Users/emmadyer/miniconda3/envs/py37/lib/python3.7/site-packages/neptune/common/utils.py", line 318, in wrapper
#     raise ConnectionLost()
# neptune.legacy.api_exceptions.ConnectionLost: Connection lost. Please try again.
